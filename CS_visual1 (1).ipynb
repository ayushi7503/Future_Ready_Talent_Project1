# %% [markdown]
# ## CUSTOMER SEGMENTATION PROJECT VISUALISATION -1

# %%
import pandas as pd

# %%
data=pd.read_csv("Train.csv")

# %%
data
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     462809    Male           No   22        No     Healthcare
# 1     462643  Female          Yes   38       Yes       Engineer
# 2     466315  Female          Yes   67       Yes       Engineer
# 3     461735    Male          Yes   67       Yes         Lawyer
# 4     462669  Female          Yes   40       Yes  Entertainment
# ...      ...     ...          ...  ...       ...            ...
# 8063  464018    Male           No   22        No            NaN
# 8064  464685    Male           No   35        No      Executive
# 8065  465406  Female           No   33       Yes     Healthcare
# 8066  467299  Female           No   27       Yes     Healthcare
# 8067  461879    Male          Yes   37       Yes      Executive
#
#       Work_Experience Spending_Score  Family_Size  Var_1 Segmentation
# 0                 1.0            Low          4.0  Cat_4            D
# ...

# %%
data.head()
# Out:
#        ID  Gender Ever_Married  Age Graduated     Profession  Work_Experience  \
# 0  462809    Male           No   22        No     Healthcare              1.0
# 1  462643  Female          Yes   38       Yes       Engineer              NaN
# 2  466315  Female          Yes   67       Yes       Engineer              1.0
# 3  461735    Male          Yes   67       Yes         Lawyer              0.0
# 4  462669  Female          Yes   40       Yes  Entertainment              NaN
#
#   Spending_Score  Family_Size  Var_1 Segmentation
# 0            Low          4.0  Cat_4            D
# 1        Average          3.0  Cat_4            A
# 2            Low          1.0  Cat_6            B
# 3           High          2.0  Cat_6            B
# 4           High          6.0  Cat_6            A

# %%
data.tail()
# Out:
#           ID  Gender Ever_Married  Age Graduated  Profession  Work_Experience  \
# 8063  464018    Male           No   22        No         NaN              0.0
# 8064  464685    Male           No   35        No   Executive              3.0
# 8065  465406  Female           No   33       Yes  Healthcare              1.0
# 8066  467299  Female           No   27       Yes  Healthcare              1.0
# 8067  461879    Male          Yes   37       Yes   Executive              0.0
#
#      Spending_Score  Family_Size  Var_1 Segmentation
# 8063            Low          7.0  Cat_1            D
# 8064            Low          4.0  Cat_4            D
# 8065            Low          1.0  Cat_6            D
# 8066            Low          4.0  Cat_6            B
# 8067        Average          3.0  Cat_4            B

# %%
data.describe()
# Out:
#                   ID          Age  Work_Experience  Family_Size
# count    8068.000000  8068.000000      7239.000000  7733.000000
# mean   463479.214551    43.466906         2.641663     2.850123
# std      2595.381232    16.711696         3.406763     1.531413
# min    458982.000000    18.000000         0.000000     1.000000
# 25%    461240.750000    30.000000         0.000000     2.000000
# 50%    463472.500000    40.000000         1.000000     3.000000
# 75%    465744.250000    53.000000         4.000000     4.000000
# max    467974.000000    89.000000        14.000000     9.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8068 entries, 0 to 8067
# Data columns (total 11 columns):
# ID                 8068 non-null int64
# Gender             8068 non-null object
# Ever_Married       7928 non-null object
# Age                8068 non-null int64
# Graduated          7990 non-null object
# Profession         7944 non-null object
# Work_Experience    7239 non-null float64
# Spending_Score     8068 non-null object
# Family_Size        7733 non-null float64
# Var_1              7992 non-null object
# Segmentation       8068 non-null object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 693.5+ KB

# %%
data.isnull().sum()
# Out:
# ID                   0
# Gender               0
# Ever_Married       140
# Age                  0
# Graduated           78
# Profession         124
# Work_Experience    829
# Spending_Score       0
# Family_Size        335
# Var_1               76
# Segmentation         0
# dtype: int64

# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt

# Create a bar plot of name vs grade
plt.bar(x=data.Age, height=data.Spending_Score)
plt.title('Customer segmentation')
plt.xlabel('Age')
plt.ylabel('Spending Score')
plt.grid(color='#95a5a6', linestyle='--', linewidth=2, axis='y', alpha=0.7)
plt.xticks(rotation=90)


# Display the plot
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize = (10,4))
ax[0].bar(x=data.Age, height=data.Spending_Score, color='orange')
ax[0].set_title('Customer Segmentation')
ax[0].set_xticklabels(data.Family_Size, rotation=90)
fig.show()

# %% [markdown]
# ### HISTOGRAM

# %%
var = data['Spending_Score']

# %%
plt.hist(var)
plt.grid(color='#189AB4', linestyle='--', linewidth=2, axis='y', alpha=0.7)
plt.show()

# %%
var1 = data["Age"]

# %%
plt.hist(var1)
plt.grid(color='#189AB4', linestyle='--', linewidth=2, axis='y', alpha=0.7)
plt.show()

# %% [markdown]
# ### BOXPLOT

# %%
ax = data[['Age']].plot(kind='box', title='boxplot', showmeans=True)

plt.show()

# %% [markdown]
# ### BARPLOT

# %%
df_sample = data[data['Age']>20]

# %%
df_sample
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     462809    Male           No   22        No     Healthcare
# 1     462643  Female          Yes   38       Yes       Engineer
# 2     466315  Female          Yes   67       Yes       Engineer
# 3     461735    Male          Yes   67       Yes         Lawyer
# 4     462669  Female          Yes   40       Yes  Entertainment
# ...      ...     ...          ...  ...       ...            ...
# 8063  464018    Male           No   22        No            NaN
# 8064  464685    Male           No   35        No      Executive
# 8065  465406  Female           No   33       Yes     Healthcare
# 8066  467299  Female           No   27       Yes     Healthcare
# 8067  461879    Male          Yes   37       Yes      Executive
#
#       Work_Experience Spending_Score  Family_Size  Var_1 Segmentation
# 0                 1.0            Low          4.0  Cat_4            D
# ...

# %%
df_sample.plot(x='Age', y=['Spending_Score','Family_Size'], kind='bar', figsize=(8,5))
plt.show()

# %%
data.Age.corr(data.Family_Size)
# Out:
# -0.28051699612988534

# %%
data.plot.scatter(title='AGE VS FAMILY SIZE', x='Age', y='Family_Size')
plt.show()

# %%
data1=df_sample.copy()

# %%
data1
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     462809    Male           No   22        No     Healthcare
# 1     462643  Female          Yes   38       Yes       Engineer
# 2     466315  Female          Yes   67       Yes       Engineer
# 3     461735    Male          Yes   67       Yes         Lawyer
# 4     462669  Female          Yes   40       Yes  Entertainment
# ...      ...     ...          ...  ...       ...            ...
# 8063  464018    Male           No   22        No            NaN
# 8064  464685    Male           No   35        No      Executive
# 8065  465406  Female           No   33       Yes     Healthcare
# 8066  467299  Female           No   27       Yes     Healthcare
# 8067  461879    Male          Yes   37       Yes      Executive
#
#       Work_Experience Spending_Score  Family_Size  Var_1 Segmentation
# 0                 1.0            Low          4.0  Cat_4            D
# ...

# %%
data1.isnull().sum()
# Out:
# ID                   0
# Gender               0
# Ever_Married       126
# Age                  0
# Graduated           71
# Profession         116
# Work_Experience    781
# Spending_Score       0
# Family_Size        310
# Var_1               73
# Segmentation         0
# dtype: int64

# %%
data1
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     462809    Male           No   22        No     Healthcare
# 1     462643  Female          Yes   38       Yes       Engineer
# 2     466315  Female          Yes   67       Yes       Engineer
# 3     461735    Male          Yes   67       Yes         Lawyer
# 4     462669  Female          Yes   40       Yes  Entertainment
# ...      ...     ...          ...  ...       ...            ...
# 8063  464018    Male           No   22        No            NaN
# 8064  464685    Male           No   35        No      Executive
# 8065  465406  Female           No   33       Yes     Healthcare
# 8066  467299  Female           No   27       Yes     Healthcare
# 8067  461879    Male          Yes   37       Yes      Executive
#
#       Work_Experience Spending_Score  Family_Size  Var_1 Segmentation
# 0                 1.0            Low          4.0  Cat_4            D
# ...

# %%
data2=data1.drop(['Var_1','Profession','ID','Segmentation'],axis=1)

# %%
data2
# Out:
#       Gender Ever_Married  Age Graduated  Work_Experience Spending_Score  \
# 0       Male           No   22        No              1.0            Low
# 1     Female          Yes   38       Yes              NaN        Average
# 2     Female          Yes   67       Yes              1.0            Low
# 3       Male          Yes   67       Yes              0.0           High
# 4     Female          Yes   40       Yes              NaN           High
# ...      ...          ...  ...       ...              ...            ...
# 8063    Male           No   22        No              0.0            Low
# 8064    Male           No   35        No              3.0            Low
# 8065  Female           No   33       Yes              1.0            Low
# 8066  Female           No   27       Yes              1.0            Low
# 8067    Male          Yes   37       Yes              0.0        Average
#
#       Family_Size
# 0             4.0
# 1             3.0
# 2             1.0
# ...

# %%
data2["Ever_Married"].fillna("NO", inplace = True)
data2["Graduated"].fillna("NO", inplace = True)
#data2["Profession"].fillna("Nil", inplace = True)
data2["Work_Experience"].fillna("0", inplace = True)
data2["Family_Size"].fillna("1", inplace = True)

# %%
data2.isnull().sum()
# Out:
# Gender             0
# Ever_Married       0
# Age                0
# Graduated          0
# Work_Experience    0
# Spending_Score     0
# Family_Size        0
# dtype: int64

# %% [markdown]
# ###  LABLE ENCODING

# %%
from sklearn.preprocessing import LabelEncoder
cols = ["Gender","Ever_Married","Graduated","Spending_Score"]
#cols = ["Credit_History"]
le=LabelEncoder()
for col in cols:
    data2[col] = le.fit_transform(data2[col])

# %%
data2
# Out:
#       Gender  Ever_Married  Age  Graduated Work_Experience  Spending_Score  \
# 0          1             1   22          1               1               2
# 1          0             2   38          2               0               0
# 2          0             2   67          2               1               2
# 3          1             2   67          2               0               1
# 4          0             2   40          2               0               1
# ...      ...           ...  ...        ...             ...             ...
# 8063       1             1   22          1               0               2
# 8064       1             1   35          1               3               2
# 8065       0             1   33          2               1               2
# 8066       0             1   27          2               1               2
# 8067       1             2   37          2               0               0
#
#      Family_Size
# 0              4
# 1              3
# ...

# %%
plt.figure(figsize=(15,5))
sns.countplot(y='Gender',data=data)
plt.show()

# %%
plt.figure(1,figsize=(15,7))
n=0
for cols in ['Age','Spending_Score','Family_Size']:
    n+=1
    plt.subplot(1,3,n)
    sns.set(style="whitegrid")
    plt.subplots_adjust(hspace=0.5,wspace=0.5)
    sns.violinplot(x=cols,y='Gender',data=data2)
    plt.ylabel('Gender'if n==1 else '')
    plt.title('voilin plot')
plt.show()

# %%
age_18_25=data.Age[(data.Age >=18)& (data.Age <=25)]
age_26_35=data.Age[(data.Age >=26)& (data.Age <=35)]
age_36_45=data.Age[(data.Age >=36)& (data.Age <=45)]
age_46_55=data.Age[(data.Age >=46)& (data.Age <=55)]
age_55above=data.Age[data.Age >=56]

agex=["18-25","26-35","36-45","46-55","55+"]
agey=[len(age_18_25.values),len(age_26_35.values),len(age_36_45.values),len(age_46_55.values),len(age_55above.values)]
plt.figure(figsize=(15,16))
sns.barplot(x=agex, y=agey, palette='mako')
plt.title('number of customer and ages')
plt.xlabel("age")
plt.ylabel("no.of customers")
plt.show()

# %% [markdown]
# ### PAIRPLOT

# %%
import seaborn as sns
sns.pairplot(data2)
plt.show()

# %%
features = data2[data2.columns[0:7]]

# %%
features
# Out:
#       Gender  Ever_Married  Age  Graduated Work_Experience  Spending_Score  \
# 0          1             1   22          1               1               2
# 1          0             2   38          2               0               0
# 2          0             2   67          2               1               2
# 3          1             2   67          2               0               1
# 4          0             2   40          2               0               1
# ...      ...           ...  ...        ...             ...             ...
# 8063       1             1   22          1               0               2
# 8064       1             1   35          1               3               2
# 8065       0             1   33          2               1               2
# 8066       0             1   27          2               1               2
# 8067       1             2   37          2               0               0
#
#      Family_Size
# 0              4
# 1              3
# ...

# %% [markdown]
# ### PCA

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA

# Normalize the numeric features so they're on the same scale
scaled_features = MinMaxScaler().fit_transform(features[data2.columns[0:7]])

# Get two principal components
pca = PCA(n_components=2).fit(scaled_features)
features_2d = pca.transform(scaled_features)
features_2d[0:7]
# Out:
# array([[-0.17813349, -0.65943597],
#        [ 0.17283576,  0.85395432],
#        [ 0.52849361,  0.12770767],
#        [-0.55884162,  0.06987008],
#        [ 0.34939524,  0.47368049],
#        [-0.72530444,  0.38806895],
#        [-0.19918021, -0.5873904 ]])

# %%
plt.scatter(features_2d[:,0],features_2d[:,1])
plt.xlabel('Dimension1')
plt.ylabel('Dimension 2')
plt.title('Data')
plt.show()

# %% [markdown]
# ### ELBOW GRAPH

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i)
    # Fit the data points
    kmeans.fit(features.values)
    # Get the WCSS (inertia) value
    wcss.append(kmeans.inertia_)
    
#Plot the WCSS values onto a line graph
plt.plot(range(1, 11), wcss)
plt.title('COUSTOMER SEGMENTAAION')
plt.xlabel('Number of clusters')
plt.show()

# %% [markdown]
# ### OPTIMUM NUMBER OF CLUSTER = 3

# %%
model = KMeans(n_clusters=3, init='k-means++', n_init=100, max_iter=1000)

# %%
km_clusters = model.fit_predict(features.values)

# %%
km_clusters
# Out:
# array([2, 2, 1, ..., 2, 2, 2], dtype=int32)

# %% [markdown]
# ### VISUALISING THE CLUSTERS

# %%
from sklearn.cluster import KMeans
import numpy as np


# k means
kmeans = KMeans(n_clusters=3, random_state=0)
data2['cluster'] = kmeans.fit_predict(data2[['Age', 'Spending_Score']])


# get centroids
centroids = kmeans.cluster_centers_
cen_x = [i[0] for i in centroids] 
cen_y = [i[1] for i in centroids]


## add to df
data2['cen_x'] = data2.cluster.map({0:cen_x[0], 1:cen_x[1] , 2:cen_x[2]})
data2['cen_y'] = data2.cluster.map({0:cen_y[0], 1:cen_y[1], 2:cen_y[2] })


# define and map colors
colors = ['#DF2020', '#81DF20', '#2095DF']
data2['c'] = data2.cluster.map({0:colors[0], 1:colors[1], 2:colors[2]})

# %%
import matplotlib.pyplot as plt
plt.scatter(data2.Age, data2.Spending_Score, c=data2.c, alpha = 0.6, s=10)
plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1], s=50 ,c='black',label='centroids')
plt.show()

# %%
plt.scatter(data2.Age, data2.Spending_Score, c=data2.c,  s=data2.Age, alpha = 0.6)
plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],s=50,c='black',label='centroids')
plt.show()

# %%
colors = ['#DF2020', '#81DF20', '#2095DF']
kmeans = KMeans(n_clusters=3, random_state=0)
data2['cluster'] = kmeans.fit_predict(data2[['Age', 'Spending_Score', 'Work_Experience']])
data2['c'] = data2.cluster.map({0:colors[0], 1:colors[1], 2:colors[2]})
fig = plt.figure(figsize=(26,6))
ax = fig.add_subplot(131, projection='3d')
ax.scatter(data2.Age, data2.Spending_Score, data2.Age, c=data2.c, s=15)
ax.set_xlabel('Age')
ax.set_ylabel('Spenidng_Score')
ax.set_zlabel('Work_Experience')
ax.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],s=50,c='black',label='centroids')
#ax.show()

# %% [markdown]
# ###  POKEMON STATS

# %%
from matplotlib.lines import Line2D


fig, ax = plt.subplots(1, figsize=(8,8))


# plot data
plt.scatter(data2.Age, data2.Spending_Score, c=data2.c, alpha = 0.6, s=10)


# plot centroids
plt.scatter(cen_x, cen_y, marker='^', c=colors, s=70)



plt.plot([data2.Age.mean()]*2, [0,200], color='black', lw=0.5, linestyle='--')
plt.xlim(0,200)



plt.plot([0,200], [data2.Spending_Score.mean()]*2, color='black', lw=0.5, linestyle='--')
plt.ylim(0,200)


# create a list of legend elemntes
## average line
legend_elements = [Line2D([0], [0], color='black', lw=0.5, linestyle='--', label='Average')]


## markers / records
cluster_leg = [Line2D([0], [0], marker='o', color='w', label='Cluster {}'.format(i+1), 
               markerfacecolor=mcolor, markersize=5) for i, mcolor in enumerate(colors)]


## centroids
cent_leg = [Line2D([0], [0], marker='^', color='w', label='Centroid - C{}'.format(i+1), 
            markerfacecolor=mcolor, markersize=10) for i, mcolor in enumerate(colors)]


# add all elements to the same list
legend_elements.extend(cluster_leg)
legend_elements.extend(cent_leg)


# plot legend
plt.legend(handles=legend_elements, loc='upper right', ncol=2)
# title and labels
plt.title('CUSTOMER SEGMENTATION', loc='left', fontsize=22)
plt.xlabel('AGE')
plt.ylabel('SPENDING SCORE')
plt.show()

# %% [markdown]
# ### LINE SEGMENT

# %%
fig, ax = plt.subplots(1, figsize=(8,8))

# plot data
plt.scatter(data2.Age, data2.Spending_Score, c=data2.c, alpha = 0.6, s=10)

# plot centroids
plt.scatter(cen_x, cen_y, marker='^', c=colors, s=70)

# plot lines
for idx, val in data2.iterrows():
    x = [val.Age, val.cen_x,]
    y = [val.Spending_Score, val.cen_y]
    plt.plot(x, y, c=val.c, alpha=0.2)
    
    
# legend
legend_elements = [Line2D([0], [0], marker='o', color='w', label='Cluster {}'.format(i+1), 
                   markerfacecolor=mcolor, markersize=5) for i, mcolor in enumerate(colors)]
legend_elements.extend([Line2D([0], [0], marker='^', color='w', label='Centroid - C{}'.format(i+1), 
            markerfacecolor=mcolor, markersize=10) for i, mcolor in enumerate(colors)])
legend_elements.extend(cent_leg)
plt.legend(handles=legend_elements, loc='upper right', ncol=2)


# x and y limits
plt.xlim(0,200)
plt.ylim(0,200)


# title and labels
plt.title('Line Segments', loc='left', fontsize=22)
plt.xlabel('Income')
plt.ylabel('DebtIncomeRatio')
plt.show()

# %%
def plot_clusters(samples, clusters):
    col_dic = {0:'blue',1:'green',2:'orange'}
    mrk_dic = {0:'*',1:'x',2:'+'}
    colors = [col_dic[x] for x in clusters]
    markers = [mrk_dic[x] for x in clusters]
    for sample in range(len(clusters)):
        plt.scatter(samples[sample][0], samples[sample][1], color = colors[sample], marker=markers[sample], s=100)
    plt.xlabel('Dimension 1')
    plt.ylabel('Dimension 2')
    plt.title('Customer Segmnetation')
    plt.show()

plot_clusters(features_2d, km_clusters)

# %%
data2
# Out:
#       Gender  Ever_Married  Age  Graduated Work_Experience  Spending_Score  \
# 0          1             1   22          1               1               2
# 1          0             2   38          2               0               0
# 2          0             2   67          2               1               2
# 3          1             2   67          2               0               1
# 4          0             2   40          2               0               1
# ...      ...           ...  ...        ...             ...             ...
# 8063       1             1   22          1               0               2
# 8064       1             1   35          1               3               2
# 8065       0             1   33          2               1               2
# 8066       0             1   27          2               1               2
# 8067       1             2   37          2               0               0
#
#      Family_Size  cluster      cen_x     cen_y        c
# ...

# %%
data2['Ever_Married'] = data2['Ever_Married'].astype('int64')

# %%
data2['Age'] = data2['Age'].astype('int64')

# %%
data2['Gender'] = data2['Gender'].astype('int64')

# %%
data2['Graduated'] = data2['Graduated'].astype('int64')

# %%
data2['Work_Experience'] = data2['Work_Experience'].astype('int64')

# %%
data2['Spending_Score'] = data2['Spending_Score'].astype('int64')

# %%
data2['Family_Size'] = data2['Family_Size'].astype('int64')

# %%
corr = data2.corr()

# %%
corr.style.background_gradient(cmap ="PuBuGn_r")
# Out:
# <style  type="text/css" >
#     #T_7f54ff34_5cbc_11ec_bd44_b780781e07fcrow0_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_7f54ff34_5cbc_11ec_bd44_b780781e07fcrow0_col1 {
#             background-color:  #4f9dc8;
#             color:  #000000;
#         }    #T_7f54ff34_5cbc_11ec_bd44_b780781e07fcrow0_col2 {
#             background-color:  #499ac6;
#             color:  #000000;
#         }    #T_7f54ff34_5cbc_11ec_bd44_b780781e07fcrow0_col3 {
#             background-color:  #016f61;
#             color:  #f1f1f1;
#         }    #T_7f54ff34_5cbc_11ec_bd44_b780781e07fcrow0_col4 {
#             background-color:  #016956;
#             color:  #f1f1f1;
#         }    #T_7f54ff34_5cbc_11ec_bd44_b780781e07fcrow0_col5 {
#             background-color:  #1d89a6;
#             color:  #000000;
#         }    #T_7f54ff34_5cbc_11ec_bd44_b780781e07fcrow0_col6 {
#             background-color:  #027f84;
#             color:  #f1f1f1;
# ...

# %%
data5=data2.drop(['cluster','cen_x','cen_y','c'],axis=1)
data5
# Out:
#       Gender  Ever_Married  Age  Graduated  Work_Experience  Spending_Score  \
# 0          1             1   22          1                1               2
# 1          0             2   38          2                0               0
# 2          0             2   67          2                1               2
# 3          1             2   67          2                0               1
# 4          0             2   40          2                0               1
# ...      ...           ...  ...        ...              ...             ...
# 8063       1             1   22          1                0               2
# 8064       1             1   35          1                3               2
# 8065       0             1   33          2                1               2
# 8066       0             1   27          2                1               2
# 8067       1             2   37          2                0               0
#
#       Family_Size
# 0               4
# ...

# %%
data5['Gender'] = data5['Gender'].astype('int64') 
data5['Age'] = data5['Age'].astype('int64') 
data5['Ever_Married'] = data5['Ever_Married'].astype('int64') 
data5['Graduated'] = data5['Graduated'].astype('int64') 
data5['Work_Experience'] = data5['Work_Experience'].astype('int64') 
data5['Spending_Score'] = data5['Spending_Score'].astype('int64') 
data5['Family_Size'] = data5['Family_Size'].astype('int64')

# %%
sns.heatmap(data5,cmap="PuBuGn_r")
plt.figure(figsize=(50,50))
plt.show()

# %%
from sklearn.metrics import roc_auc_score

# %%
def plot_roc_curve(fpr, tpr):
    plt.plot(fpr, tpr, color='orange', label='ROC')
    plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend()
    plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model2 = KNeighborsClassifier(n_neighbors=4)

# %%
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_classification

# %%
X, y = make_classification(n_samples=1000, n_classes=2, n_features=20, random_state=27)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=27)

# %%
model2 = KNeighborsClassifier(n_neighbors=4)

# %%
model2
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=4, p=2,
#                      weights='uniform')

# %% [markdown]
# #![Screenshot 2021-12-08 at 7.57.29 PM.png](attachment:8fcb8b06-758b-4dd8-a7b8-b2c2df356e22.png)
